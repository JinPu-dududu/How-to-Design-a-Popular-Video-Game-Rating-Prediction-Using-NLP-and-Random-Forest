# %%
import pickle
# Restore from a file
f = open('review_game.p', 'rb')
df = pickle.load(f)

# %%
df['reviewText'] = df['reviewText'].astype(str)
df['reviewText'].head()
# Out:
# 0    Good game. Good graphics. A bit of a learning ...
# 1    If you buy this game, you will regret it.  If ...
# 2    This game is a bit hard to get the hang of, bu...
# 3    seems like it would be an interesting game but...
# 4    I played it a while but it was alright. The st...
# Name: reviewText, dtype: object

# %%
apikey = 'N4qaNRrjD5xCwk2hFNvDw_AaWJ_yDADkv96ueuMWNNOZ'
url = 'https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/42f361bc-4cce-4639-b79f-fede5ffdbf02'

# %%
#https://cloud.ibm.com/apidocs/natural-language-understanding/natural-language-understanding
# !pip install --upgrade "ibm-watson>=4.3.0"
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, KeywordsOptions, EmotionOptions, SentimentOptions

authenticator = IAMAuthenticator(apikey)
natural_language_understanding = NaturalLanguageUnderstandingV1(version='2019-07-12',authenticator=authenticator)

natural_language_understanding.set_service_url(url)

# %% [markdown]
# # Get keyword list

# %%
from sklearn.utils import shuffle
import pandas as pd
import numpy
from nltk import FreqDist
import nltk
from wordcloud import WordCloud, STOPWORDS
from nltk.stem.porter import *

most_common_all = []
word_key_list_all = []
for k in range(10):
    df = shuffle(df)
    df.reset_index(inplace=True, drop=True)
    bins = 10
    cut = pd.cut(df.index,bins,labels=False)
    df['cut'] = cut
    df.groupby('cut').mean()['length']
    
    keylist = []
    for i in range(bins):
        text = ' '.join(df[df['cut']==i]['reviewText'])
        text = text.lower()
        j = json.loads((get_emotion(text)))
        for i in range(len(j['keywords'])):
            keylist.append(j['keywords'][i]['text'])
    keywords = ' '.join(set(keylist))
    print(len(set(keylist)))
            
    p_stemmer = PorterStemmer()
    word_list = nltk.word_tokenize(keywords)
    stopwords = list(STOPWORDS) + ['game','good','great','better','best','love','much','awesome','fun','play','lot','alot','only','little','time']
    words = [p_stemmer.stem(word) for word in word_list if p_stemmer.stem(word) not in stopwords and word not in stopwords and word.isalpha()] 
    # words = [word for word in word_list if word not in stopwords and word.isalpha()] 
    most_common = FreqDist(words).most_common()
    most_common_all.extend(most_common)
    
    word_key_list = []
    for i in most_common:
        key = []
        word = i[0]
        freq = i[1]
        for s in set(keylist):
            if word in [p_stemmer.stem(word) for word in nltk.word_tokenize(s)]:
                key.append(s)
        word_key_list.append((word,freq,key))
    word_key_list_all.extend(word_key_list)
# Out:
# 445
# 428
# 436
# 447
# 429
# 440
# 439
# 431
# 448
# 444

# %%
most_common_dict = dict()
for i in most_common_all:
    if most_common_dict.get(i[0]):
        most_common_dict[i[0]] += i[1]
    else:
        most_common_dict[i[0]] = i[1]

# %%
sorted_most_common = sorted(most_common_dict.items(),key=lambda x:x[1],reverse=True)
sorted_most_common
# Out:
# [('new', 126),
#  ('first', 113),
#  ('thing', 100),
#  ('charact', 98),
#  ('mode', 92),
#  ('use', 84),
#  ('differ', 83),
#  ('level', 80),
#  ('player', 79),
#  ('graphic', 74),
#  ('stori', 69),
#  ('fan', 69),
#  ('old', 64),
#  ('bad', 61),
#  ('look', 61),
#  ('buy', 59),
#  ('version', 59),
#  ('control', 47),
#  ('real', 45),
#  ('seri', 41),
#  ('year', 40),
#  ('part', 39),
#  ('favorit', 39),
#  ('fight', 37),
#  ('system', 36),
#  ('race', 36),
#  ('video', 35),
#  ('gameplay', 34),
#  ('way', 34),
#  ('featur', 34),
#  ('battl', 34),
#  ('origin', 34),
#  ('review', 32),
#  ('work', 31),
#  ('final', 31),
#  ('action', 30),
#  ('sound', 30),
#  ('last', 28),
#  ('weapon', 27),
#  ('nice', 27),
#  ('whole', 27),
#  ('cool', 27),
#  ('fantasi', 26),
#  ('music', 26),
#  ('move', 26),
#  ('easi', 26),
#  ('line', 25),
#  ('worst', 24),
#  ('mario', 24),
#  ('feel', 24),
#  ('long', 23),
#  ('hard', 23),
#  ('take', 23),
#  ('world', 23),
#  ('greatest', 23),
#  ('singl', 23),
#  ('car', 23),
#  ('big', 23),
#  ('main', 22),
#  ('start', 22),
#  ('team', 22),
#  ('style', 21),
#  ('strategi', 21),
#  ('hour', 20),
#  ('rpg', 20),
#  ('parti', 20),
#  ('boss', 19),
#  ('classic', 19),
#  ('peopl', 19),
#  ('mission', 18),
#  ('run', 18),
#  ('star', 18),
#  ('problem', 18),
#  ('war', 18),
#  ('end', 18),
#  ('arcad', 18),
#  ('basebal', 17),
#  ('condit', 17),
#  ('type', 17),
#  ('card', 16),
#  ('qualiti', 16),
#  ('wii', 16),
#  ('addit', 16),
#  ('excel', 16),
#  ('shooter', 16),
#  ('high', 15),
#  ('valu', 15),
#  ('guy', 15),
#  ('copi', 15),
#  ('metal', 15),
#  ('challeng', 15),
#  ('ton', 15),
#  ('huge', 15),
#  ('perfect', 15),
#  ('given', 15),
#  ('replay', 14),
#  ('effect', 14),
#  ('enemi', 14),
#  ('need', 14),
#  ('actual', 14),
#  ('evil', 14),
#  ('multiplay', 14),
#  ('onlin', 14),
#  ('option', 14),
#  ('experi', 13),
#  ('consol', 13),
#  ('titl', 13),
#  ('mini', 13),
#  ('let', 13),
#  ('bit', 13),
#  ('person', 13),
#  ('set', 13),
#  ('ad', 13),
#  ('sport', 13),
#  ('wrestl', 13),
#  ('resid', 12),
#  ('comput', 12),
#  ('second', 12),
#  ('gear', 12),
#  ('number', 12),
#  ('kid', 12),
#  ('gun', 12),
#  ('save', 12),
#  ('horror', 12),
#  ('varieti', 11),
#  ('previou', 11),
#  ('monster', 11),
#  ('make', 11),
#  ('voic', 11),
#  ('realist', 11),
#  ('reason', 11),
#  ('friend', 11),
#  ('releas', 11),
#  ('special', 11),
#  ('complet', 11),
#  ('footbal', 11),
#  ('son', 11),
#  ('day', 11),
#  ('boy', 11),
#  ('turn', 11),
#  ('season', 10),
#  ('gener', 10),
#  ('price', 10),
#  ('older', 10),
#  ('playstat', 10),
#  ('tripl', 10),
#  ('dreamcast', 10),
#  ('stuff', 10),
#  ('basketbal', 10),
#  ('point', 10),
#  ('skill', 10),
#  ('amaz', 10),
#  ('sega', 10),
#  ('madden', 10),
#  ('place', 10),
#  ('product', 10),
#  ('digimon', 10),
#  ('combat', 10),
#  ('free', 9),
#  ('area', 9),
#  ('job', 9),
#  ('deal', 9),
#  ('shot', 9),
#  ('interest', 9),
#  ('call', 9),
#  ('design', 9),
#  ('difficulti', 9),
#  ('xbox', 9),
#  ('true', 9),
#  ('major', 9),
#  ('aspect', 8),
#  ('puzzl', 8),
#  ('light', 8),
#  ('detail', 8),
#  ('load', 8),
#  ('nintendo', 8),
#  ('live', 8),
#  ('chang', 8),
#  ('tri', 8),
#  ('u', 8),
#  ('camera', 8),
#  ('next', 8),
#  ('item', 8),
#  ('develop', 8),
#  ('advanc', 8),
#  ('coupl', 8),
#  ('edit', 8),
#  ('attack', 8),
#  ('basic', 8),
#  ('adventur', 8),
#  ('god', 8),
#  ('beat', 8),
#  ('anim', 8),
#  ('track', 8),
#  ('stupid', 8),
#  ('select', 7),
#  ('right', 7),
#  ('movi', 7),
#  ('extra', 7),
#  ('worth', 7),
#  ('zelda', 7),
#  ('mech', 7),
#  ('decent', 7),
#  ('short', 7),
#  ('nfl', 7),
#  ('find', 7),
#  ('bonu', 7),
#  ('gba', 7),
#  ('idea', 7),
#  ('power', 7),
#  ('plot', 7),
#  ('storylin', 7),
#  ('fighter', 7),
#  ('platform', 7),
#  ('twist', 7),
#  ('campaign', 7),
#  ('night', 7),
#  ('school', 7),
#  ('futur', 7),
#  ('solid', 7),
#  ('kart', 7),
#  ('map', 7),
#  ('one', 7),
#  ('kind', 7),
#  ('duti', 7),
#  ('full', 7),
#  ('back', 7),
#  ('man', 7),
#  ('gamecub', 7),
#  ('biggest', 7),
#  ('warrior', 7),
#  ('piec', 7),
#  ('damag', 6),
#  ('sonic', 6),
#  ('choic', 6),
#  ('abil', 6),
#  ('disc', 6),
#  ('hit', 6),
#  ('gameboy', 6),
#  ('word', 6),
#  ('term', 6),
#  ('issu', 6),
#  ('movement', 6),
#  ('golden', 6),
#  ('screen', 6),
#  ('go', 6),
#  ('magic', 6),
#  ('horribl', 6),
#  ('depth', 6),
#  ('want', 6),
#  ('later', 6),
#  ('combo', 6),
#  ('scene', 6),
#  ('half', 6),
#  ('disk', 6),
#  ('simul', 6),
#  ('drive', 6),
#  ('theme', 6),
#  ('side', 6),
#  ('minut', 6),
#  ('pokemon', 6),
#  ('bunch', 5),
#  ('help', 5),
#  ('legend', 5),
#  ('wrestler', 5),
#  ('chapter', 5),
#  ('kill', 5),
#  ('improv', 5),
#  ('speed', 5),
#  ('luck', 5),
#  ('sure', 5),
#  ('lack', 5),
#  ('gamer', 5),
#  ('element', 5),
#  ('vii', 5),
#  ('golf', 5),
#  ('ball', 5),
#  ('franchis', 5),
#  ('collect', 5),
#  ('overal', 5),
#  ('playabl', 5),
#  ('show', 5),
#  ('newer', 5),
#  ('standard', 5),
#  ('core', 5),
#  ('difficult', 5),
#  ('exampl', 5),
#  ('station', 5),
#  ('ps', 5),
#  ('cours', 5),
#  ('maker', 5),
#  ('space', 5),
#  ('stick', 5),
#  ('hunt', 5),
#  ('cover', 5),
#  ('expans', 5),
#  ('nba', 5),
#  ('effort', 5),
#  ('suck', 5),
#  ('doesnt', 5),
#  ('wwe', 5),
#  ('stage', 5),
#  ('engin', 5),
#  ('fast', 5),
#  ('pace', 5),
#  ('quick', 5),
#  ('halo', 5),
#  ('hockey', 5),
#  ('danc', 5),
#  ('soccer', 5),
#  ('career', 5),
#  ('grand', 5),
#  ('deep', 4),
#  ('news', 4),
#  ('dynasti', 4),
#  ('marvel', 4),
#  ('open', 4),
#  ('lesser', 4),
#  ('silent', 4),
#  ('beauti', 4),
#  ('name', 4),
#  ('super', 4),
#  ('simpl', 4),
#  ('act', 4),
#  ('mechan', 4),
#  ('dark', 4),
#  ('sun', 4),
#  ('oppon', 4),
#  ('fantast', 4),
#  ('ground', 4),
#  ('forc', 4),
#  ('top', 4),
#  ('form', 4),
#  ('funni', 4),
#  ('content', 4),
#  ('match', 4),
#  ('cut', 4),
#  ('gundam', 4),
#  ('incred', 4),
#  ('cast', 4),
#  ('color', 4),
#  ('board', 4),
#  ('internet', 4),
#  ('total', 4),
#  ('wonder', 4),
#  ('endless', 4),
#  ('famili', 4),
#  ('sort', 4),
#  ('children', 4),
#  ('life', 4),
#  ('addict', 4),
#  ('european', 4),
#  ('touch', 4),
#  ('ii', 4),
#  ('trick', 4),
#  ('week', 4),
#  ('concept', 4),
#  ('latest', 4),
#  ('ncaa', 4),
#  ('saturn', 4),
#  ('unit', 4),
#  ('street', 4),
#  ('romp', 4),
#  ('dragon', 4),
#  ('angl', 4),
#  ('small', 4),
#  ('member', 4),
#  ('memori', 4),
#  ('surviv', 4),
#  ('cpu', 4),
#  ('rate', 4),
#  ('current', 4),
#  ('fire', 4),
#  ('poor', 4),
#  ('none', 4),
#  ('interact', 4),
#  ('mk', 4),
#  ('ship', 4),
#  ('ds', 4),
#  ('ne', 4),
#  ('instal', 4),
#  ('limit', 4),
#  ('pick', 4),
#  ('crash', 4),
#  ('racer', 4),
#  ('spiderman', 4),
#  ('compani', 4),
#  ('uniqu', 4),
#  ('c', 3),
#  ('weak', 3),
#  ('progress', 3),
#  ('known', 3),
#  ('formula', 3),
#  ('machin', 3),
#  ('typic', 3),
#  ('keep', 3),
#  ('dozen', 3),
#  ('clip', 3),
#  ('freez', 3),
#  ('launch', 3),
#  ('physic', 3),
#  ('sim', 3),
#  ('damn', 3),
#  ('neg', 3),
#  ('grandia', 3),
#  ('enough', 3),
#  ('strang', 3),
#  ('modern', 3),
#  ('nostalgia', 3),
#  ('pc', 3),
#  ('pitch', 3),
#  ('visual', 3),
#  ('cant', 3),
#  ('wait', 3),
#  ('metro', 3),
#  ('command', 3),
#  ('videogam', 3),
#  ('castlevania', 3),
#  ('worm', 3),
#  ('innov', 3),
#  ('human', 3),
#  ('smooth', 3),
#  ('citi', 3),
#  ('age', 3),
#  ('crazi', 3),
#  ('song', 3),
#  ('frogger', 3),
#  ('flaw', 3),
#  ('variou', 3),
#  ('op', 3),
#  ('case', 3),
#  ('sweet', 3),
#  ('hardest', 3),
#  ('na', 3),
#  ('impress', 3),
#  ('hand', 3),
#  ('servic', 3),
#  ('seller', 3),
#  ('custom', 3),
#  ('page', 3),
#  ('dead', 3),
#  ('psone', 3),
#  ('analog', 3),
#  ('mg', 3),
#  ('air', 3),
#  ('fp', 3),
#  ('eye', 3),
#  ('bore', 3),
#  ('wwf', 3),
#  ('countless', 3),
#  ('book', 3),
#  ('tomb', 3),
#  ('raider', 3),
#  ('young', 3),
#  ('curs', 3),
#  ('factor', 3),
#  ('em', 3),
#  ('ocarina', 3),
#  ('fact', 3),
#  ('cartridg', 3),
#  ('smackdown', 3),
#  ('higher', 3),
#  ('blood', 3),
#  ('futurist', 3),
#  ('port', 3),
#  ('doubl', 3),
#  ('motion', 3),
#  ('film', 3),
#  ('model', 3),
#  ('pleasur', 3),
#  ('dungeon', 3),
#  ('batman', 3),
#  ('throw', 3),
#  ('favourit', 3),
#  ('hill', 3),
#  ('daughter', 3),
#  ('money', 3),
#  ('mean', 3),
#  ('stroke', 3),
#  ('creatur', 3),
#  ('stat', 3),
#  ('gripe', 3),
#  ('altern', 3),
#  ('normal', 3),
#  ('outstand', 3),
#  ('reaver', 3),
#  ('soul', 3),
#  ('walk', 3),
#  ('contra', 3),
#  ('posit', 3),
#  ('megaman', 3),
#  ('cabl', 3),
#  ('encount', 3),
#  ('combin', 3),
#  ('shape', 3),
#  ('test', 3),
#  ('function', 3),
#  ('success', 3),
#  ('creat', 3),
#  ('slow', 3),
#  ('snowboard', 3),
#  ('hype', 3),
#  ('complaint', 3),
#  ('break', 3),
#  ('fli', 3),
#  ('popular', 3),
#  ('newest', 3),
#  ('quest', 3),
#  ('tale', 3),
#  ('ff', 3),
#  ('disappoint', 3),
#  ('roll', 3),
#  ('decis', 3),
#  ('lag', 3),
#  ('black', 3),
#  ('tenchu', 2),
#  ('cof', 2),
#  ('amazon', 2),
#  ('oper', 2),
#  ('ambient', 2),
#  ('nois', 2),
#  ('drop', 2),
#  ('x', 2),
#  ('assault', 2),
#  ('rifl', 2),
#  ('round', 2),
#  ('got', 2),
#  ('ta', 2),
#  ('us', 2),
#  ('freedom', 2),
#  ('sheer', 2),
#  ('skin', 2),
#  ('chao', 2),
#  ('winner', 2),
#  ('rare', 2),
#  ('girl', 2),
#  ('tradit', 2),
#  ('excelent', 2),
#  ('jump', 2),
#  ('entir', 2),
#  ('conduct', 2),
#  ('rt', 2),
#  ('heat', 2),
#  ('genr', 2),
#  ('avid', 2),
#  ('ive', 2),
#  ('remotley', 2),
#  ('redeem', 2),
#  ('leagu', 2),
#  ('vs', 2),
#  ('averag', 2),
#  ('killzon', 2),
#  ('spin', 2),
#  ('snake', 2),
#  ('crowd', 2),
#  ('button', 2),
#  ('longest', 2),
#  ('rule', 2),
#  ('dont', 2),
#  ('demo', 2),
#  ('solo', 2),
#  ('igt', 2),
#  ('slot', 2),
#  ('cost', 2),
#  ('sharp', 2),
#  ('defens', 2),
#  ('freestyl', 2),
#  ('creativ', 2),
#  ('capabl', 2),
#  ('tenni', 2),
#  ('ddr', 2),
#  ('scari', 2),
#  ('empir', 2),
#  ('dbz', 2),
#  ('z', 2),
#  ('build', 2),
#  ('qb', 2),
#  ('coolest', 2),
#  ('pikmin', 2),
#  ('brutal', 2),
#  ('ea', 2),
#  ('joystick', 2),
#  ('death', 2),
#  ('powerup', 2),
#  ('auction', 2),
#  ('random', 2),
#  ('gon', 2),
#  ('countri', 2),
#  ('mix', 2),
#  ('read', 2),
#  ('pictur', 2),
#  ('phantasi', 2),
#  ('dive', 2),
#  ('shop', 2),
#  ('bigger', 2),
#  ('menu', 2),
#  ('creator', 2),
#  ('object', 2),
#  ('didnt', 2),
#  ('nt', 2),
#  ('ghost', 2),
#  ('hold', 2),
#  ('sad', 2),
#  ('setup', 2),
#  ('focal', 2),
#  ('mp', 2),
#  ('receiv', 2),
#  ('torin', 2),
#  ('sidekick', 2),
#  ('plenti', 2),
#  ('fog', 2),
#  ('moment', 2),
#  ('retro', 2),
#  ('jame', 2),
#  ('jrpg', 2),
#  ('intens', 2),
#  ('cd', 2),
#  ('aria', 2),
#  ('sorrow', 2),
#  ('treat', 2),
#  ('downsid', 2),
#  ('biowar', 2),
#  ('definit', 2),
#  ('base', 2),
#  ('sword', 2),
#  ('recruit', 2),
#  ('home', 2),
#  ('distinct', 2),
#  ('pak', 2),
#  ('regular', 2),
#  ('view', 2),
#  ('meet', 2),
#  ('stop', 2),
#  ('town', 2),
#  ('made', 2),
#  ('troubl', 2),
#  ('hope', 2),
#  ('epic', 2),
#  ('novel', 2),
#  ('childhood', 2),
#  ('rumbl', 2),
#  ('colleg', 2),
#  ('capcom', 2),
#  ('espn', 2),
#  ('critic', 2),
#  ('cloud', 2),
#  ('harder', 2),
#  ('figur', 2),
#  ('starcraft', 2),
#  ('coh', 2),
#  ('d', 2),
#  ('mii', 2),
#  ('ol', 2),
#  ('possibl', 2),
#  ('scroll', 2),
#  ('store', 2),
#  ('water', 2),
#  ('aim', 2),
#  ('godzilla', 2),
#  ('note', 2),
#  ('period', 2),
#  ('tournament', 2),
#  ('entranc', 2),
#  ('lost', 2),
#  ('gore', 2),
#  ('hair', 2),
#  ('derbi', 2),
#  ('grace', 2),
#  ('goal', 2),
#  ('youll', 2),
#  ('vagrant', 2),
#  ('sne', 2),
#  ('faster', 2),
#  ('head', 2),
#  ('balanc', 2),
#  ('art', 2),
#  ('kinda', 2),
#  ('dialogu', 2),
#  ('purchas', 2),
#  ('atmospher', 2),
#  ('today', 2),
#  ('strike', 2),
#  ('zone', 2),
#  ('joy', 2),
#  ('practic', 2),
#  ('surpris', 2),
#  ('casual', 2),
#  ('compon', 2),
#  ('shoot', 2),
#  ('crew', 2),
#  ('useless', 2),
#  ('say', 2),
#  ('armi', 2),
#  ('men', 2),
#  ('ninja', 2),
#  ('toni', 2),
#  ('hawk', 2),
#  ('lego', 2),
#  ('hilari', 2),
#  ('connect', 2),
#  ('younger', 2),
#  ('child', 2),
#  ('minigam', 2),
#  ('think', 2),
#  ('shadow', 2),
#  ('novelti', 2),
#  ('donkey', 2),
#  ('kong', 2),
#  ('code', 2),
#  ('bomb', 2),
#  ('larg', 2),
#  ('owner', 2),
#  ('hero', 2),
#  ('train', 2),
#  ('wise', 2),
#  ('red', 2),
#  ('slower', 2),
#  ('diment', 2),
#  ('numer', 2),
#  ('frame', 2),
#  ('easier', 2),
#  ('wolfenstein', 2),
#  ('link', 2),
#  ('fifa', 2),
#  ('updat', 2),
#  ('bandicoot', 2),
#  ('stand', 2),
#  ('prix', 2),
#  ('wcw', 2),
#  ('gt', 2),
#  ('vampir', 2),
#  ('blade', 2),
#  ('attent', 2),
#  ('tactic', 2),
#  ('jedi', 2),
#  ('sprite', 2),
#  ('novic', 2),
#  ('prais', 2),
#  ('laugh', 2),
#  ('expens', 2),
#  ('lineup', 2),
#  ('result', 2),
#  ('mani', 2),
#  ('plane', 2),
#  ('ring', 2),
#  ('fritz', 2),
#  ('baseman', 2),
#  ('nhl', 2),
#  ('blend', 2),
#  ('auto', 2),
#  ('question', 2),
#  ('click', 2),
#  ('arena', 2),
#  ('lunar', 2),
#  ('market', 2),
#  ('dang', 2),
#  ('gratif', 2),
#  ('indycar', 2),
#  ('nickelodeon', 2),
#  ('class', 2),
#  ('delight', 2),
#  ('opposit', 2),
#  ('late', 2),
#  ('commentari', 2),
#  ('duck', 2),
#  ('clair', 2),
#  ('redfield', 2),
#  ('sens', 2),
#  ('ass', 2),
#  ('month', 2),
#  ('potenti', 2),
#  ('method', 2),
#  ('gen', 2),
#  ('packag', 2),
#  ('everi', 2),
#  ('traction', 2),
#  ('remot', 2),
#  ('date', 2),
#  ('odd', 2),
#  ('ultim', 2),
#  ('inclus', 2),
#  ('linear', 2),
#  ('indefinit', 1),
#  ('amount', 1),
#  ('fastest', 1),
#  ('win', 1),
#  ('hint', 1),
#  ('jam', 1),
#  ('maximum', 1),
#  ('destruct', 1),
#  ('magnific', 1),
#  ('princess', 1),
#  ('peach', 1),
#  ('mimim', 1),
#  ('backtrack', 1),
#  ('excit', 1),
#  ('western', 1),
#  ('immedi', 1),
#  ('ofther', 1),
#  ('degre', 1),
#  ('dock', 1),
#  ('adict', 1),
#  ('ride', 1),
#  ('reali', 1),
#  ('modifi', 1),
#  ('render', 1),
#  ('less', 1),
#  ('famicom', 1),
#  ('raiden', 1),
#  ('rain', 1),
#  ('user', 1),
#  ('raid', 1),
#  ('workout', 1),
#  ('wierd', 1),
#  ('averga', 1),
#  ('amus', 1),
#  ('le', 1),
#  ('serpent', 1),
#  ('roug', 1),
#  ('aventur', 1),
#  ('mare', 1),
#  ('soldier', 1),
#  ('stroll', 1),
#  ('id', 1),
#  ('intim', 1),
#  ('untouch', 1),
#  ('woh', 1),
#  ('bye', 1),
#  ('overview', 1),
#  ('smarter', 1),
#  ('desicion', 1),
#  ('tag', 1),
#  ('sequenc', 1),
#  ('boomstick', 1),
#  ('hole', 1),
#  ('introduct', 1),
#  ('witcher', 1),
#  ('duel', 1),
#  ('trek', 1),
#  ('outdat', 1),
#  ('tank', 1),
#  ('undemand', 1),
#  ('soni', 1),
#  ('enjoy', 1),
#  ('hot', 1),
#  ('gm', 1),
#  ('mouth', 1),
#  ('bettter', 1),
#  ('gaug', 1),
#  ('addtion', 1),
#  ('childish', 1),
#  ('lead', 1),
#  ('record', 1),
#  ('accompani', 1),
#  ('n', 1),
#  ('crappi', 1),
#  ('mob', 1),
#  ('aint', 1),
#  ('mass', 1),
#  ('minatur', 1),
#  ('energi', 1),
#  ('wealth', 1),
#  ('dgital', 1),
#  ('matur', 1),
#  ('skip', 1),
#  ('offlin', 1),
#  ('lover', 1),
#  ('crude', 1),
#  ('convers', 1),
#  ('offens', 1),
#  ('band', 1),
#  ('scarier', 1),
#  ('stake', 1),
#  ('psx', 1),
#  ('earth', 1),
#  ('repair', 1),
#  ('contrast', 1),
#  ('everyth', 1),
#  ('wide', 1),
#  ('key', 1),
#  ('mommi', 1),
#  ('g', 1),
#  ('competit', 1),
#  ('imagin', 1),
#  ('colonel', 1),
#  ('caw', 1),
#  ('olymp', 1),
#  ('liberti', 1),
#  ('athlet', 1),
#  ('arsen', 1),
#  ('assoc', 1),
#  ('storytel', 1),
#  ('nerdi', 1),
#  ('dissapoint', 1),
#  ('tempo', 1),
#  ('picross', 1),
#  ('banjo', 1),
#  ('leisur', 1),
#  ('enigmat', 1),
#  ('sheet', 1),
#  ('sluggish', 1),
#  ('assassin', 1),
#  ('creed', 1),
#  ('consul', 1),
#  ('librari', 1),
#  ('group', 1),
#  ('charect', 1),
#  ('unlockubl', 1),
#  ('exhibit', 1),
#  ('mighti', 1),
#  ('poo', 1),
#  ('gorgeou', 1),
#  ('palm', 1),
#  ('struck', 1),
#  ('ac', 1),
#  ('yard', 1),
#  ('interfac', 1),
#  ('bonus', 1),
#  ('ineffect', 1),
#  ('strength', 1),
#  ('stem', 1),
#  ('replica', 1),
#  ('sophist', 1),
#  ('fever', 1),
#  ('mj', 1),
#  ('ezio', 1),
#  ('nigth', 1),
#  ('rental', 1),
#  ('understand', 1),
#  ('centuri', 1),
#  ('deriv', 1),
#  ('brother', 1),
#  ('rugger', 1),
#  ('aw', 1),
#  ('rest', 1),
#  ('essenc', 1),
#  ('legaia', 1),
#  ('pso', 1),
#  ('luv', 1),
#  ('greater', 1),
#  ('warn', 1),
#  ('recon', 1),
#  ('pain', 1),
#  ('thespian', 1),
#  ('footag', 1),
#  ('heart', 1),
#  ('goemon', 1),
#  ('hidden', 1),
#  ('cohes', 1),
#  ('singel', 1),
#  ('pathet', 1),
#  ('thwe', 1),
#  ('acclaim', 1),
#  ('execut', 1),
#  ('goofi', 1),
#  ('cartoon', 1),
#  ('japanes', 1),
#  ('hader', 1),
#  ('lazi', 1),
#  ('earlier', 1),
#  ('rayman', 1),
#  ('sunderland', 1),
#  ('feedback', 1),
#  ('ladi', 1),
#  ('adapt', 1),
#  ('left', 1),
#  ('field', 1),
#  ('endor', 1),
#  ('bet', 1),
#  ('attitud', 1),
#  ('vengeanc', 1),
#  ('similar', 1),
#  ('fashion', 1),
#  ('ticket', 1),
#  ('costa', 1),
#  ('motorcycl', 1),
#  ('gp', 1),
#  ('viscer', 1),
#  ('cinima', 1),
#  ('everyday', 1),
#  ('loos', 1),
#  ('al', 1),
#  ('array', 1),
#  ('seed', 1),
#  ('uninspir', 1),
#  ('preciou', 1),
#  ('tick', 1),
#  ('tm', 1),
#  ('happi', 1),
#  ('dolphin', 1),
#  ('gloomi', 1),
#  ('polish', 1),
#  ('suttl', 1),
#  ('mistak', 1),
#  ('write', 1),
#  ('talent', 1),
#  ('youu', 1),
#  ('south', 1),
#  ('park', 1),
#  ('fix', 1),
#  ...]

# %%
word_key_list_dict = dict()
for i in word_key_list_all:
    if word_key_list_dict.get(i[0]):
        word_key_list_dict[i[0]] = list(set(word_key_list_dict[i[0]]+i[2]))
    else:
        word_key_list_dict[i[0]] = i[2]

# %%
word_key_list_dict['player']
# Out:
# ['retro player',
#  'player death match',
#  'player name',
#  'tennis player',
#  'single player',
#  'expeerenced hm player',
#  'cpu players',
#  'single player campaign',
#  'player control',
#  'good players',
#  'party of other players',
#  'star player',
#  'today video game players',
#  'fastest players',
#  'player play',
#  'new player',
#  'player wants',
#  'better look of the player movements',
#  'yor player',
#  'best players',
#  'novice player',
#  'best player',
#  'good player control',
#  'player option',
#  'game players',
#  'best tennis player',
#  'impatient players',
#  'human players',
#  'single easy player',
#  'single player mode',
#  'single player mini games',
#  'actuall player',
#  'single player game',
#  'dedicated players',
#  'great player',
#  'hang of the single player skiing circuit',
#  'single player missions',
#  'new players of the resident evil franchise',
#  "game's player editor",
#  'cpu player',
#  'difficulty level of each computer player',
#  'good player',
#  'best mlb player',
#  'casual player',
#  "player's style",
#  'nfl players assoc',
#  'number of players',
#  'left field player',
#  'player mode',
#  'player functions',
#  'player interaction',
#  'player tournament',
#  'lament of innocence let players',
#  'bad players',
#  'own players',
#  'computer player leaves pieces',
#  'player game',
#  'ability of the created players',
#  'players progress',
#  'hard core racing game player',
#  'player compatibility',
#  'single player story mode',
#  'first time players of asb2003',
#  'novice players',
#  'player starts',
#  'player action']
